# %%
F.<x> = GF(2)[]
K.<a> = GF(2^163, modulus=x^163 + x^7 + x^6 + x^3 + 1)

# Generate random polynomials
poly1 = K.random_element()
poly2 = K.random_element()

# Multiply
product = poly1 * poly2

print("degree: {}".format(F(product).degree()))

print(f"Poly1: 0x{poly1.integer_representation():041x}")
print(f"Poly2: 0x{poly2.integer_representation():041x}")
print(f"Product: 0x{product.integer_representation():041x}")
# Out:
# degree: 162
# Poly1: 0x343e67d80d45f09e1a268e46a63dee29f60b9790e
# Poly2: 0x363a04b2302f08d0b7ed9402a19dc22ef552785d8
# Product: 0x69a5a55d9090137c3b811b97ceb8c63eb77c43e1b

# %%
F.<x> = GF(2)[]
K.<a> = GF(2^31)

s1 = "74"
s2 = "06f9"

# Convert hex to field elements
f1 = K.fetch_int(int(s1.lower(), 16))
f2 = K.fetch_int(int(s2.lower(), 16))

print("Modulus: {} \n".format(K.modulus()))

# Perform various operations
f3 = f1 * f2
print("({}) * ({}) \n = {} \n = {:08x}".format(f1, f2, f3, f3.integer_representation()))
# Out:
# Modulus: x^31 + x^3 + 1
#
# 16
# (a^6 + a^5 + a^4 + a^2) * (a^10 + a^9 + a^7 + a^6 + a^5 + a^4 + a^3 + 1)
#  = a^16 + a^12 + a^10 + a^8 + a^4 + a^2
#  = 00011514

# %%
F.<x> = GF(2)[]
M = x^163 + x^7 + x^6 + x^3 + 1
K.<a> = GF(2^163, modulus = M)

s1 = "0x0644192702d2623c11c05c3196ee6490c8f4927ce5"
s2 = "0x04ef895f49b9b91e352a6c05dd3136d6e5249dae50"
f1 = K.fetch_int(int(s1.lower().replace("0x", ""), 16))
f2 = K.fetch_int(int(s2.lower().replace("0x", ""), 16))

#f1 = K.random_element()
#f2 = K.random_element()
f3 = f1 * f2
f4 = 1 / f1
f5 = 1 / f2
f6 = 1 / f3

f7 = f1 ** (2 ** 6)
f8 = f1 ** (2 ** 4)

f9 = f1 ** (f2.integer_representation())

print(" f1 = {} \n\n f2 = {} \n\n f3 = {} \n\n".format(f1, f2, f3))


print(" HEX FORMAT: \n f1 = {} \n f2 = {} \n f3 = {} \n f4 = {} \n f5 = {} \n f6 = {} \n f7 = {} \n f8 = {} \n f9 = {} \n".format(
    f"0x{f1.integer_representation():048x}", 
    f"0x{f2.integer_representation():048x}",
    f"0x{f3.integer_representation():048x}",
    f"0x{f4.integer_representation():048x}",
    f"0x{f5.integer_representation():048x}", 
    f"0x{f6.integer_representation():048x}", 
    f"0x{f7.integer_representation():048x}", 
    f"0x{f8.integer_representation():048x}", 
    f"0x{f9.integer_representation():048x}")
)

tmp = K(x)
for i in range(1, 24):
    tmp = tmp ** 2
f"0x{tmp.integer_representation():048x}"
# Out:
#  f1 = a^162 + a^161 + a^158 + a^154 + a^148 + a^147 + a^144 + a^141 + a^138 + a^137 + a^136 + a^129 + a^127 + a^126 + a^124 + a^121 + a^118 + a^117 + a^113 + a^109 + a^108 + a^107 + a^106 + a^100 + a^96 + a^95 + a^94 + a^86 + a^84 + a^83 + a^82 + a^77 + a^76 + a^72 + a^71 + a^68 + a^66 + a^65 + a^63 + a^62 + a^61 + a^59 + a^58 + a^57 + a^54 + a^53 + a^50 + a^47 + a^44 + a^39 + a^38 + a^35 + a^31 + a^30 + a^29 + a^28 + a^26 + a^23 + a^20 + a^17 + a^14 + a^13 + a^12 + a^11 + a^10 + a^7 + a^6 + a^5 + a^2 + 1
#
#  f2 = a^162 + a^159 + a^158 + a^157 + a^155 + a^154 + a^153 + a^152 + a^151 + a^147 + a^144 + a^142 + a^140 + a^139 + a^138 + a^137 + a^136 + a^134 + a^131 + a^128 + a^127 + a^125 + a^124 + a^123 + a^120 + a^119 + a^117 + a^116 + a^115 + a^112 + a^108 + a^107 + a^106 + a^105 + a^101 + a^100 + a^98 + a^96 + a^93 + a^91 + a^89 + a^86 + a^85 + a^83 + a^82 + a^74 + a^72 + a^71 + a^70 + a^68 + a^67 + a^66 + a^64 + a^61 + a^60 + a^56 + a^53 + a^52 + a^50 + a^49 + a^47 + a^46 + a^44 + a^42 + a^41 + a^39 + a^38 + a^37 + a^34 + a^32 + a^29 + a^26 + a^23 + a^20 + a^19 + a^18 + a^16 + a^15 + a^13 + a^11 + a^10 + a^9 + a^6 + a^4
#
#  f3 = a^162 + a^161 + a^159 + a^157 + a^156 + a^152 + a^150 + a^148 + a^147 + a^145 + a^142 + a^140 + a^138 + a^137 + a^134 + a^131 + a^129 + a^127 + a^125 + a^123 + a^122 + a^121 + a^120 + a^118 + a^116 + a^115 + a^114 + a^113 + a^110 + a^109 + a^108 + a^107 + a^106 + a^104 + a^103 + a^102 + a^101 + a^100 + a^99 + a^95 + a^94 + a^92 + a^90 + a^86 + a^81 + a^78 + a^75 + a^74 + a^65 + a^64 + a^63 + a^61 + a^60 + a^59 + a^58 + a^53 + a^52 + a^50 + a^48 + a^47 + a^45 + a^44 + a^43 + a^42 + a^40 + a^38 + a^37 + a^36 + a^35 + a^34 + a^29 + a^27 + a^26 + a^22 + a^21 + a^16 + a^15 + a^14 + a^13 + a^8 + a^6 + a^5 + a^4 + a^3 + a^2 + a
#
#
#  HEX FORMAT:
#  f1 = 0x0000000644192702d2623c11c05c3196ee6490c8f4927ce5
#  f2 = 0x00000004ef895f49b9b91e352a6c05dd3136d6e5249dae50
#  f3 = 0x00000006b15a564aaf5e7df8d4424c03bc35bd7c2c61e17e
#  f4 = 0x00000002fbca818f7ebbfb003b6318ff7c959ed1281782ea
#  f5 = 0x000000031e49c95bfa16c6b85d5cd2c3abe1e2f071c68e92
#  f6 = 0x00000000c9b5d404e46e8e8db628198f32a1f3f8972dab36
#  f7 = 0x00000000450b6a50952ac24a14d9f76f3ace3589d834f43f
#  f8 = 0x000000024cacd7866a2f9d4925076fbffd9aacf1c84c3337
#  f9 = 0x00000006da1d5965226836a80b556c2c98b9800ad80999e3
# '0x00000007d3c42a760306f4aef2abe85562f9330810bf5ca8'

# %%
f2 ** f1.integer_representation()
# Out:
# a^162 + a^159 + a^158 + a^156 + a^153 + a^152 + a^148 + a^147 + a^146 + a^144 + a^142 + a^141 + a^140 + a^138 + a^137 + a^136 + a^135 + a^133 + a^132 + a^131 + a^129 + a^127 + a^123 + a^122 + a^121 + a^119 + a^117 + a^115 + a^113 + a^111 + a^110 + a^108 + a^105 + a^103 + a^101 + a^100 + a^99 + a^98 + a^95 + a^93 + a^89 + a^88 + a^85 + a^82 + a^81 + a^76 + a^73 + a^71 + a^69 + a^68 + a^67 + a^66 + a^62 + a^61 + a^60 + a^59 + a^58 + a^56 + a^55 + a^51 + a^50 + a^49 + a^44 + a^40 + a^38 + a^37 + a^36 + a^31 + a^30 + a^29 + a^28 + a^24 + a^23 + a^22 + a^20 + a^18 + a^16 + a^15 + a^14 + a^12 + a^10 + a^9 + a^8 + a^2

# %%
d = [1945168, 3000905, 7652571, 5464110, 1172306, 6895415, 3924567, 2, 0]
m = 1 << 23
result = 0
for i in range(len(d)):
    result = result + d[i] * (m ** i)
print(f"0x{result:048x}")
# Out:
# 0x00000004ef895f49b9b91e352a6c05dd3136d6e5249dae50
